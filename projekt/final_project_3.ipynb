# %%
#Color printing
from termcolor import colored

#General data operations library
import math
import numpy as np
import pandas as pd
import ast
import glob
import functools

#The tensorflow library
import tensorflow  as tf

#Plotting libraries
import matplotlib.pyplot as plt

#Increase plots font size
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (10, 7),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

import importlib
import sys
sys.path.append("/Users/jakubkusmierski/Desktop/Uczenie_Maszynowe_2/modules")

#Private functions
import plotting_functions as plf
importlib.reload(plf);

import project as project
importlib.reload(project);

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
data_dir = '/Users/jakubkusmierski/Desktop/Uczenie_Maszynowe_2/data/sieci/'
csv_files = glob.glob(data_dir + "Higgs*.csv")

# %%
dfs = []

for file in csv_files:
    df = pd.read_csv(file)

    for col in ['tau.pt', 'tau.eta', 'tau.phi', 'H.pt', 'H.eta', 'H.phi']:
        df[col] = df[col].apply(ast.literal_eval)

    
    df['tau1_pt'] = df['tau.pt'].apply(lambda x: x[0])
    df['tau2_pt'] = df['tau.pt'].apply(lambda x: x[1])
    df['tau1_eta'] = df['tau.eta'].apply(lambda x: x[0])
    df['tau2_eta'] = df['tau.eta'].apply(lambda x: x[1])
    df['tau1_phi'] = df['tau.phi'].apply(lambda x: x[0])
    df['tau2_phi'] = df['tau.phi'].apply(lambda x: x[1])
    df['H_pt'] = df['H.pt'].apply(lambda x: x[0])
    df['H_eta'] = df['H.eta'].apply(lambda x: x[0])
    df['H_phi'] = df['H.phi'].apply(lambda x: x[0])

    df.drop(columns=['tau.pt', 'tau.eta', 'tau.phi', 'H.pt', 'H.eta', 'H.phi'], inplace=True)

    dfs.append(df)

# %%
df = pd.concat(dfs, ignore_index=True)
df.head()
# Out:
#          H.m        H.E     t1.m        t1.E     t2.m       t2.E        METx  \
# 0  196.73200  282.94920  1.77682  184.299360  1.77682   98.64985  -50.879560
# 1  170.96394  454.64020  1.77682  127.403140  1.77682  327.23706  236.432200
# 2  403.04907  770.57380  1.77682  453.754670  1.77682  316.81910   18.701082
# 3  218.99274  233.65942  1.77682  108.677956  1.77682  124.98147  -43.222538
# 4  234.15674  251.93723  1.77682   99.779755  1.77682  152.15747  104.295290
#
#         METy    trueMETx    trueMETy  ...  type2     tau1_pt    tau2_pt  \
# 0  -7.675525  -52.073196  -13.297127  ...     -1   76.953780   98.63361
# 1 -97.585000  246.659970 -110.700200  ...     -1  124.511536  228.12059
# 2  -1.000554   14.325636   21.218117  ...     -1   90.911680  252.49693
# 3 -18.162619  -33.788174   -6.049116  ...     -1  102.301540  117.20386
# 4  -8.689900   90.916330   -2.842107  ...     -1   76.937290  137.41629
#
#    tau1_eta  tau2_eta  tau1_phi  tau2_phi        H_pt     H_eta     H_phi
# 0  1.519704 -0.002149 -2.765061  1.797632  115.700005  1.164141  2.515362
# 1  0.214641  0.901347 -0.984634 -0.233547  330.250270  0.726369 -0.493766
# 2 -2.290618 -0.699414 -2.556309  0.778071  164.195970 -2.063401  0.884353
# 3 -0.350866 -0.362030  0.301128 -2.878016   15.459115 -2.346176 -3.129083
# 4  0.752438 -0.458990  2.402238 -0.038647   92.950200 -0.019375  0.524304
#
# [5 rows x 31 columns]

# %%
print(colored("Columns in the dataset:\n", 'green'), df.columns.values)
print(colored("Shape of the dataset:\n", 'red'), df.shape)
# Out:
# Columns in the dataset:
#  ['H.m' 'H.E' 't1.m' 't1.E' 't2.m' 't2.E' 'METx' 'METy' 'trueMETx'
#  'trueMETy' 'dm1' 'pt1' 'eta1' 'phi1' 'mass1' 'type1' 'dm2' 'pt2' 'eta2'
#  'phi2' 'mass2' 'type2' 'tau1_pt' 'tau2_pt' 'tau1_eta' 'tau2_eta'
#  'tau1_phi' 'tau2_phi' 'H_pt' 'H_eta' 'H_phi']
# Shape of the dataset:
#  (35586, 31)

# %%
input_features = [
    'dm1', 'pt1', 'eta1', 'phi1', 'mass1',
    'dm2', 'pt2', 'eta2', 'phi2', 'mass2',
    'trueMETx', 'trueMETy'
]

output_targets = [
    'H.m', 'H_pt', 'H_eta', 'H_phi',
    't1.m', 'tau1_pt', 'tau1_eta', 'tau1_phi',
    't2.m', 'tau2_pt', 'tau2_eta', 'tau2_phi'
]


output_targets = ['H.m', 'H_pt','tau1_pt','tau2_pt']


#output_targets = ['H.m', 'H_pt']

# %%
features = df[input_features].astype('float32').values
labels = df[output_targets].astype('float32').values

# %%
dataset = tf.data.Dataset.from_tensor_slices((features, labels))

print(colored("Dataset:\n", 'blue'), dataset)
print(colored("Dataset length:\n", 'green'), len(features))
# Out:
# Dataset:
#  <_TensorSliceDataset element_spec=(TensorSpec(shape=(12,), dtype=tf.float32, name=None), TensorSpec(shape=(4,), dtype=tf.float32, name=None))>
# Dataset length:
#  35586
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749807629.968063 19622711 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1749807629.968084 19622711 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
nStepsPerEpoch = project.nStepsPerEpoch
batchSize = project.batchSize
output_shape = len(output_targets)
buffor_size = project.buffor_size

minval = 5.0
maxval = 55.0
mean = 0.0
stddev = 1.0
rho_min = -1.0
rho_max = 1.0

adding_smeard_MET = functools.partial(project.add_smeared_MET, minval=minval, maxval=maxval, mean=mean, stddev=stddev, rho_min=rho_min, rho_max=rho_max)

dataset_train_preaper = dataset.batch(batchSize).map(adding_smeard_MET).take(nStepsPerEpoch).cache()

item = next(iter(dataset_train_preaper))
print(colored("Features shape:", "blue"), item[0].shape)
print(colored("Labels shape:", "blue"), item[1].shape)
# Out:
# Features shape: (128, 17)
# Labels shape: (128, 4)

# %%
project.plot_MET(dataset_train_preaper)

# %%
dataset_train = dataset_train_preaper.map(project.remove_true_MET).cache()

item = next(iter(dataset_train))
print(colored("Features shape:", "blue"), item[0].shape)
print(colored("Labels shape:", "blue"), item[1].shape)
# Out:
# Features shape: (128, 15)
# Labels shape: (128, 4)

# %% [markdown]
# ## Model FCNN

# %%
model_fc = tf.keras.Sequential(layers=[
    tf.keras.Input(shape=(15,), name="model_input"),
    
    tf.keras.layers.Normalization(),
    
    tf.keras.layers.Dense(64, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),

    tf.keras.layers.Dense(128, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),

    tf.keras.layers.Dense(256, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),
    
    tf.keras.layers.Dense(128, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),
    
    tf.keras.layers.Dense(64, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),
    
    tf.keras.layers.Dense(32, activation='relu',
        bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
        kernel_initializer='he_normal'),

    tf.keras.layers.Dense(output_shape, activation='relu', name="output") 
], name="FC_regression_model")

model_fc.summary()
# Out:
# Model: "FC_regression_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 15)             │            31 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,763 (335.02 KB)
#  Trainable params: 85,732 (334.89 KB)
#  Non-trainable params: 31 (128.00 B)

# %%
total_dataset = dataset_train.shuffle(buffor_size).cache()
val_batches = total_dataset.take(128)
train_batches = total_dataset.skip(128)

importlib.reload(project);

model_fc = project.trainModel(model_fc, train_data=train_batches, val_data=val_batches, nEpochs=300)
# Out:
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749807631.768859 19622711 meta_optimizer.cc:967] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8038 - loss: 431.3771 - val_accuracy: 0.9146 - val_loss: 238.2300
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9216 - loss: 242.7542 - val_accuracy: 0.9149 - val_loss: 208.8563
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9225 - loss: 211.1756 - val_accuracy: 0.9152 - val_loss: 186.9975
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9224 - loss: 198.0061 - val_accuracy: 0.9152 - val_loss: 179.3745
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9220 - loss: 192.3229 - val_accuracy: 0.9149 - val_loss: 173.5068
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9222 - loss: 188.0866 - val_accuracy: 0.9154 - val_loss: 171.7111
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9227 - loss: 185.6978 - val_accuracy: 0.9156 - val_loss: 170.5227
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9230 - loss: 182.9192 - val_accuracy: 0.9150 - val_loss: 168.3771
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9234 - loss: 181.0549 - val_accuracy: 0.9148 - val_loss: 167.3022
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9232 - loss: 178.9459 - val_accuracy: 0.9151 - val_loss: 167.4223
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9231 - loss: 177.6084 - val_accuracy: 0.9155 - val_loss: 167.3805
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9241 - loss: 176.1149 - val_accuracy: 0.9147 - val_loss: 166.2531
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9246 - loss: 174.8780 - val_accuracy: 0.9151 - val_loss: 165.5705
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9244 - loss: 173.5525 - val_accuracy: 0.9156 - val_loss: 164.7768
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9249 - loss: 173.0990 - val_accuracy: 0.9146 - val_loss: 164.6732
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9248 - loss: 172.2369 - val_accuracy: 0.9141 - val_loss: 164.2124
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9259 - loss: 171.4376 - val_accuracy: 0.9140 - val_loss: 164.0327
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9264 - loss: 170.8385 - val_accuracy: 0.9135 - val_loss: 163.9675
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9261 - loss: 170.4526 - val_accuracy: 0.9125 - val_loss: 163.1373
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9258 - loss: 169.4108 - val_accuracy: 0.9129 - val_loss: 163.2735
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9268 - loss: 168.6468 - val_accuracy: 0.9133 - val_loss: 163.1963
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9278 - loss: 167.7931 - val_accuracy: 0.9129 - val_loss: 163.3816
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9268 - loss: 167.4474 - val_accuracy: 0.9125 - val_loss: 163.1798
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9280 - loss: 166.3349 - val_accuracy: 0.9129 - val_loss: 163.2115
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9281 - loss: 165.7675 - val_accuracy: 0.9125 - val_loss: 163.0571
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9279 - loss: 165.2844 - val_accuracy: 0.9134 - val_loss: 163.2717
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9282 - loss: 164.5938 - val_accuracy: 0.9127 - val_loss: 164.2558
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9281 - loss: 164.5583 - val_accuracy: 0.9119 - val_loss: 163.7680
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9283 - loss: 163.7515 - val_accuracy: 0.9125 - val_loss: 164.0006
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9290 - loss: 163.4237 - val_accuracy: 0.9122 - val_loss: 164.5124
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9299 - loss: 162.5799 - val_accuracy: 0.9124 - val_loss: 164.2772
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9296 - loss: 162.1117 - val_accuracy: 0.9105 - val_loss: 164.6769
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9297 - loss: 161.7975 - val_accuracy: 0.9117 - val_loss: 165.4498
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9306 - loss: 161.4363 - val_accuracy: 0.9120 - val_loss: 165.9782
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9292 - loss: 162.2787 - val_accuracy: 0.9116 - val_loss: 164.0365
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9289 - loss: 161.4213 - val_accuracy: 0.9118 - val_loss: 164.1731
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9286 - loss: 160.2716 - val_accuracy: 0.9121 - val_loss: 163.4922
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9307 - loss: 159.1988 - val_accuracy: 0.9126 - val_loss: 162.9628
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9308 - loss: 159.0633 - val_accuracy: 0.9119 - val_loss: 162.7678
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9302 - loss: 157.4011 - val_accuracy: 0.9130 - val_loss: 163.1662
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9304 - loss: 156.7945 - val_accuracy: 0.9122 - val_loss: 162.9790
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9314 - loss: 155.4119 - val_accuracy: 0.9128 - val_loss: 163.5811
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9318 - loss: 154.5058 - val_accuracy: 0.9133 - val_loss: 163.9444
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9323 - loss: 154.2025 - val_accuracy: 0.9131 - val_loss: 164.3694
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9320 - loss: 153.6245 - val_accuracy: 0.9115 - val_loss: 163.7185
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9310 - loss: 153.8728 - val_accuracy: 0.9125 - val_loss: 163.6852
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9309 - loss: 152.4531 - val_accuracy: 0.9122 - val_loss: 163.5282
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9315 - loss: 151.6177 - val_accuracy: 0.9130 - val_loss: 164.0903
# Epoch 49/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9318 - loss: 151.3945 - val_accuracy: 0.9127 - val_loss: 164.0470
# Epoch 50/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9339 - loss: 151.0165 - val_accuracy: 0.9115 - val_loss: 164.5009
# Epoch 51/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9338 - loss: 150.4380 - val_accuracy: 0.9122 - val_loss: 164.7173
# Epoch 52/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9337 - loss: 149.9091 - val_accuracy: 0.9117 - val_loss: 164.6926
# Epoch 53/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9334 - loss: 149.6745 - val_accuracy: 0.9119 - val_loss: 164.7150
# Epoch 54/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9349 - loss: 149.1120 - val_accuracy: 0.9119 - val_loss: 164.8524
# Epoch 54: early stopping
# Evaluation on training dataset:
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9109 - loss: 164.4124

# %%
project.plot_H_mass(model_fc, val_batches)

# %%
project.true_vs_predict_H_mass(model_fc, val_batches)

# %%
project.plot_all_labels(model_fc, val_batches, output_targets)
# Out:
# True Higgs mass:  172.41812  and predicted: 135.12624

# %%
project.plot_all_pulls(model_fc, val_batches, output_targets)
# Out:
# [H.m] sigma = 105.3699
# [H_pt] sigma = 68.8701
# [tau1_pt] sigma = 44.4872
# [tau2_pt] sigma = 44.1510

# %% [markdown]
# ## Model architektury dwugałęziowej

# %%
dataset_train_test = dataset_train.unbatch()
dataset_split = dataset_train_test.map(project.split_inputs).batch(batchSize).cache()

total_dataset = dataset_split.shuffle(buffor_size).cache()
val_batches = total_dataset.take(128)
train_batches = total_dataset.skip(128)

# %%
input_particles = tf.keras.Input(shape=(10,), name="particles_input")
input_met = tf.keras.Input(shape=(5,), name="met_input")

# Gałąź cząstek
norm_particles = tf.keras.layers.Normalization()(input_particles)
x1 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(norm_particles)
x1 = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x1)

# Gałąź MET
norm_met = tf.keras.layers.Normalization()(input_met)
x2 = tf.keras.layers.Dense(32, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(norm_met)
x2 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x2)

# Połączenie
x = tf.keras.layers.concatenate([x1, x2])
x = tf.keras.layers.Dense(256, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
x = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
x = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
output = tf.keras.layers.Dense(output_shape, activation='linear', name='output')(x)

model_dual = tf.keras.Model(inputs={'particles_input': input_particles, 'met_input': input_met}, outputs=output)

model_dual.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ particles_input     │ (None, 10)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ met_input           │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1     │ (None, 10)        │         21 │ particles_input[… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_2     │ (None, 5)         │         11 │ met_input[0][0]   │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │        704 │ normalization_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │        192 │ normalization_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │      8,320 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      2,112 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 192)       │          0 │ dense_7[0][0],    │
# │ (Concatenate)       │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │     49,408 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 128)       │     32,896 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 64)        │      8,256 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 4)         │        260 │ dense_12[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 102,180 (399.15 KB)
#  Trainable params: 102,148 (399.02 KB)
#  Non-trainable params: 32 (136.00 B)

# %%
importlib.reload(project);

model_dual = project.trainModel(model_dual, train_data=train_batches, val_data=val_batches, nEpochs=300);
# Out:
# Epoch 1/300
# E0000 00:00:1749807760.859697 19622711 meta_optimizer.cc:967] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
#     148/Unknown 4s 15ms/step - accuracy: 0.7647 - loss: 330.3131
# /opt/anaconda3/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.7665 - loss: 328.6645 - val_accuracy: 0.9150 - val_loss: 207.0303
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9132 - loss: 182.0435 - val_accuracy: 0.9164 - val_loss: 193.4250
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9152 - loss: 175.2945 - val_accuracy: 0.9161 - val_loss: 190.9379
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9152 - loss: 170.2157 - val_accuracy: 0.9166 - val_loss: 183.8234
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9166 - loss: 166.2840 - val_accuracy: 0.9170 - val_loss: 181.8684
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9172 - loss: 162.6698 - val_accuracy: 0.9182 - val_loss: 177.0960
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9178 - loss: 159.7225 - val_accuracy: 0.9167 - val_loss: 175.1806
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9175 - loss: 157.2179 - val_accuracy: 0.9172 - val_loss: 173.0100
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9177 - loss: 155.3906 - val_accuracy: 0.9172 - val_loss: 173.5480
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9178 - loss: 153.6316 - val_accuracy: 0.9182 - val_loss: 172.5061
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9184 - loss: 152.5878 - val_accuracy: 0.9185 - val_loss: 172.0155
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9188 - loss: 151.4949 - val_accuracy: 0.9186 - val_loss: 172.8032
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9190 - loss: 150.8064 - val_accuracy: 0.9179 - val_loss: 173.6986
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9187 - loss: 149.8622 - val_accuracy: 0.9165 - val_loss: 173.7794
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9190 - loss: 149.5857 - val_accuracy: 0.9177 - val_loss: 171.8012
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9191 - loss: 148.6172 - val_accuracy: 0.9171 - val_loss: 171.4942
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9195 - loss: 148.4315 - val_accuracy: 0.9164 - val_loss: 170.5058
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9194 - loss: 147.7224 - val_accuracy: 0.9165 - val_loss: 170.1960
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9198 - loss: 146.9191 - val_accuracy: 0.9162 - val_loss: 167.2184
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9202 - loss: 145.6414 - val_accuracy: 0.9161 - val_loss: 167.1928
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9212 - loss: 144.8505 - val_accuracy: 0.9161 - val_loss: 166.8635
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9204 - loss: 144.0665 - val_accuracy: 0.9158 - val_loss: 167.1716
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9215 - loss: 143.4887 - val_accuracy: 0.9147 - val_loss: 167.2253
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9211 - loss: 143.0944 - val_accuracy: 0.9133 - val_loss: 166.9103
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9217 - loss: 142.5161 - val_accuracy: 0.9126 - val_loss: 166.8196
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9224 - loss: 141.7910 - val_accuracy: 0.9115 - val_loss: 166.9755
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9215 - loss: 141.3724 - val_accuracy: 0.9127 - val_loss: 167.4122
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9223 - loss: 140.5769 - val_accuracy: 0.9111 - val_loss: 166.9036
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9225 - loss: 140.1496 - val_accuracy: 0.9122 - val_loss: 167.5108
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9231 - loss: 139.9092 - val_accuracy: 0.9103 - val_loss: 167.3409
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9228 - loss: 139.4592 - val_accuracy: 0.9105 - val_loss: 167.0617
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9237 - loss: 138.7513 - val_accuracy: 0.9101 - val_loss: 167.8615
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9231 - loss: 138.2926 - val_accuracy: 0.9117 - val_loss: 166.5825
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9246 - loss: 137.8868 - val_accuracy: 0.9101 - val_loss: 167.4930
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9245 - loss: 137.4424 - val_accuracy: 0.9099 - val_loss: 167.1888
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9251 - loss: 136.5837 - val_accuracy: 0.9106 - val_loss: 167.2857
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9247 - loss: 136.3317 - val_accuracy: 0.9127 - val_loss: 166.5940
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9257 - loss: 135.8746 - val_accuracy: 0.9091 - val_loss: 167.8716
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9254 - loss: 135.0568 - val_accuracy: 0.9105 - val_loss: 167.1680
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9269 - loss: 134.4469 - val_accuracy: 0.9102 - val_loss: 166.8717
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9273 - loss: 133.6290 - val_accuracy: 0.9091 - val_loss: 167.8167
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9273 - loss: 133.1876 - val_accuracy: 0.9096 - val_loss: 165.8580
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9273 - loss: 132.2386 - val_accuracy: 0.9099 - val_loss: 166.2028
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9282 - loss: 131.5460 - val_accuracy: 0.9108 - val_loss: 164.7928
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9288 - loss: 130.6245 - val_accuracy: 0.9115 - val_loss: 165.3587
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9291 - loss: 130.3978 - val_accuracy: 0.9090 - val_loss: 164.6234
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9296 - loss: 129.3407 - val_accuracy: 0.9104 - val_loss: 164.5335
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9303 - loss: 128.8771 - val_accuracy: 0.9111 - val_loss: 163.8399
# Epoch 49/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9317 - loss: 128.1896 - val_accuracy: 0.9098 - val_loss: 164.2771
# Epoch 50/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9302 - loss: 127.9501 - val_accuracy: 0.9121 - val_loss: 163.0223
# Epoch 51/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9310 - loss: 126.8435 - val_accuracy: 0.9111 - val_loss: 163.9779
# Epoch 52/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9332 - loss: 126.3800 - val_accuracy: 0.9110 - val_loss: 162.8725
# Epoch 53/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9330 - loss: 126.0852 - val_accuracy: 0.9119 - val_loss: 163.0837
# Epoch 54/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9333 - loss: 125.2149 - val_accuracy: 0.9139 - val_loss: 163.3365
# Epoch 55/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9325 - loss: 125.0415 - val_accuracy: 0.9111 - val_loss: 164.0734
# Epoch 56/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9337 - loss: 124.7625 - val_accuracy: 0.9115 - val_loss: 164.4563
# Epoch 57/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9341 - loss: 124.7337 - val_accuracy: 0.9131 - val_loss: 163.3897
# Epoch 58/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9349 - loss: 123.8683 - val_accuracy: 0.9117 - val_loss: 163.5651
# Epoch 59/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9348 - loss: 123.0410 - val_accuracy: 0.9136 - val_loss: 163.1859
# Epoch 60/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9349 - loss: 122.7327 - val_accuracy: 0.9130 - val_loss: 162.3685
# Epoch 61/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9354 - loss: 122.1747 - val_accuracy: 0.9147 - val_loss: 161.9534
# Epoch 62/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9360 - loss: 121.7711 - val_accuracy: 0.9149 - val_loss: 161.2355
# Epoch 63/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9356 - loss: 121.4630 - val_accuracy: 0.9160 - val_loss: 160.9113
# Epoch 64/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9354 - loss: 120.8137 - val_accuracy: 0.9144 - val_loss: 160.9632
# Epoch 65/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9353 - loss: 120.3991 - val_accuracy: 0.9150 - val_loss: 160.7492
# Epoch 66/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9350 - loss: 119.8600 - val_accuracy: 0.9155 - val_loss: 160.6489
# Epoch 67/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9360 - loss: 119.4186 - val_accuracy: 0.9160 - val_loss: 160.7057
# Epoch 68/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9360 - loss: 119.1529 - val_accuracy: 0.9156 - val_loss: 159.9658
# Epoch 69/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9359 - loss: 118.3092 - val_accuracy: 0.9155 - val_loss: 160.5181
# Epoch 70/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9356 - loss: 117.7359 - val_accuracy: 0.9157 - val_loss: 160.0558
# Epoch 71/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9370 - loss: 117.1479 - val_accuracy: 0.9164 - val_loss: 159.9159
# Epoch 72/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9384 - loss: 117.0172 - val_accuracy: 0.9160 - val_loss: 159.7653
# Epoch 73/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9400 - loss: 116.2508 - val_accuracy: 0.9178 - val_loss: 159.6130
# Epoch 74/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9382 - loss: 116.4015 - val_accuracy: 0.9160 - val_loss: 159.8654
# Epoch 75/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9388 - loss: 115.9284 - val_accuracy: 0.9175 - val_loss: 158.5618
# Epoch 76/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9378 - loss: 115.9259 - val_accuracy: 0.9175 - val_loss: 158.1221
# Epoch 77/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9396 - loss: 115.1849 - val_accuracy: 0.9180 - val_loss: 157.7946
# Epoch 78/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9401 - loss: 114.1556 - val_accuracy: 0.9175 - val_loss: 157.6313
# Epoch 79/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9406 - loss: 113.9036 - val_accuracy: 0.9178 - val_loss: 157.8757
# Epoch 80/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9422 - loss: 112.9411 - val_accuracy: 0.9172 - val_loss: 158.2595
# Epoch 81/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9424 - loss: 112.7458 - val_accuracy: 0.9165 - val_loss: 157.8841
# Epoch 82/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9409 - loss: 112.1366 - val_accuracy: 0.9180 - val_loss: 158.2837
# Epoch 83/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9427 - loss: 111.8076 - val_accuracy: 0.9181 - val_loss: 157.5309
# Epoch 84/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9422 - loss: 111.3281 - val_accuracy: 0.9183 - val_loss: 157.3947
# Epoch 85/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9430 - loss: 111.0886 - val_accuracy: 0.9182 - val_loss: 158.3142
# Epoch 86/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9430 - loss: 110.5245 - val_accuracy: 0.9182 - val_loss: 158.2747
# Epoch 87/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9455 - loss: 110.3598 - val_accuracy: 0.9180 - val_loss: 157.6105
# Epoch 88/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9449 - loss: 109.8281 - val_accuracy: 0.9184 - val_loss: 158.1530
# Epoch 89/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9450 - loss: 109.3905 - val_accuracy: 0.9185 - val_loss: 158.0545
# Epoch 90/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9459 - loss: 108.7132 - val_accuracy: 0.9167 - val_loss: 158.5031
# Epoch 91/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9450 - loss: 108.3209 - val_accuracy: 0.9179 - val_loss: 158.3743
# Epoch 92/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9461 - loss: 107.9311 - val_accuracy: 0.9178 - val_loss: 158.9997
# Epoch 93/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9477 - loss: 107.7544 - val_accuracy: 0.9183 - val_loss: 158.0304
# Epoch 94/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9470 - loss: 107.9771 - val_accuracy: 0.9178 - val_loss: 158.2198
# Epoch 95/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9481 - loss: 107.3640 - val_accuracy: 0.9183 - val_loss: 158.0080
# Epoch 96/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9476 - loss: 106.9801 - val_accuracy: 0.9180 - val_loss: 157.9950
# Epoch 97/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9471 - loss: 106.7972 - val_accuracy: 0.9177 - val_loss: 158.2207
# Epoch 98/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9485 - loss: 106.3953 - val_accuracy: 0.9173 - val_loss: 157.7912
# Epoch 99/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9486 - loss: 105.9963 - val_accuracy: 0.9180 - val_loss: 157.7760
# Epoch 99: early stopping
# Evaluation on training dataset:
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9200 - loss: 154.4965

# %%
project.plot_H_mass(model_dual, val_batches)

# %%
project.true_vs_predict_H_mass(model_dual, val_batches)

# %%
project.plot_all_labels(model_dual, train_batches, output_targets)
# Out:
# True Higgs mass:  121.06224  and predicted: 146.08455

# %%
project.plot_all_pulls(model_dual, val_batches, output_targets)
# Out:
# [H.m] sigma = 99.0008
# [H_pt] sigma = 57.8575
# [tau1_pt] sigma = 43.1577
# [tau2_pt] sigma = 44.1883

# %% [markdown]
# ## Model architektury trójgałęziowej

# %%
dataset_train_test = dataset_train.unbatch()
dataset_split2 = dataset_train_test.map(project.split_inputs2).batch(batchSize).cache()

total_dataset = dataset_split2.shuffle(buffor_size).cache()
val_batches = total_dataset.take(128)
train_batches = total_dataset.skip(128)

# %%
input_particles1 = tf.keras.Input(shape=(5,), name="particles_input1")
input_particles2 = tf.keras.Input(shape=(5,), name="particles_input2")
input_met = tf.keras.Input(shape=(5,), name="met_input")

# Gałąź cząstek - 1
norm_particles1 = tf.keras.layers.Normalization()(input_particles1)
x1 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(norm_particles1)
x1 = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x1)

# Gałąź cząstek - 2
norm_particles2 = tf.keras.layers.Normalization()(input_particles2)
x2 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(norm_particles2)
x2 = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x2)


#Połączona gałąź cząstek
x12 = tf.keras.layers.concatenate([x1, x2])
x12 = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x12)
x12 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x12)

# Gałąź MET
norm_met = tf.keras.layers.Normalization()(input_met)
x3 = tf.keras.layers.Dense(32, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(norm_met)
x3 = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x3)

# Połączenie
x = tf.keras.layers.concatenate([x12, x3])
x = tf.keras.layers.Dense(256, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
x = tf.keras.layers.Dense(128, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
x = tf.keras.layers.Dense(64, activation='relu',
                          bias_initializer=tf.keras.initializers.RandomUniform(minval=-1, maxval=1),
                          kernel_initializer='he_normal')(x)
output = tf.keras.layers.Dense(output_shape, activation='linear', name='output')(x)

model_dual2 = tf.keras.Model(inputs={'particles_input1': input_particles1, 'particles_input2': input_particles2, 'met_input': input_met}, outputs=output)

model_dual2.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ particles_input1    │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ particles_input2    │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_3     │ (None, 5)         │         11 │ particles_input1… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_4     │ (None, 5)         │         11 │ particles_input2… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 64)        │        384 │ normalization_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 64)        │        384 │ normalization_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 128)       │      8,320 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 128)       │      8,320 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ met_input           │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 256)       │          0 │ dense_14[0][0],   │
# │ (Concatenate)       │                   │            │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_5     │ (None, 5)         │         11 │ met_input[0][0]   │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 128)       │     32,896 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 32)        │        192 │ normalization_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 64)        │      8,256 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64)        │      2,112 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128)       │          0 │ dense_18[0][0],   │
# │ (Concatenate)       │                   │            │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 256)       │     33,024 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │     32,896 │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 64)        │      8,256 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 4)         │        260 │ dense_23[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 135,333 (528.66 KB)
#  Trainable params: 135,300 (528.52 KB)
#  Non-trainable params: 33 (144.00 B)

# %%
importlib.reload(project);

model_dual2 = project.trainModel(model_dual2, train_data=train_batches, val_data=val_batches, nEpochs=300);
# Out:
# Epoch 1/300
# E0000 00:00:1749808026.342108 19622711 meta_optimizer.cc:967] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6552 - loss: 527.3277 - val_accuracy: 0.9177 - val_loss: 243.7683
# Epoch 2/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8598 - loss: 226.2074 - val_accuracy: 0.9174 - val_loss: 201.9399
# Epoch 3/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8849 - loss: 207.9038 - val_accuracy: 0.8890 - val_loss: 200.9204
# Epoch 4/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8982 - loss: 199.2301 - val_accuracy: 0.9146 - val_loss: 181.8828
# Epoch 5/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9106 - loss: 186.0775 - val_accuracy: 0.9168 - val_loss: 173.5194
# Epoch 6/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9119 - loss: 178.7342 - val_accuracy: 0.9165 - val_loss: 169.5760
# Epoch 7/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9123 - loss: 175.1184 - val_accuracy: 0.9169 - val_loss: 167.0194
# Epoch 8/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9144 - loss: 173.3800 - val_accuracy: 0.9175 - val_loss: 168.9433
# Epoch 9/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9160 - loss: 170.9858 - val_accuracy: 0.9182 - val_loss: 168.0940
# Epoch 10/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9167 - loss: 168.5921 - val_accuracy: 0.9196 - val_loss: 167.2543
# Epoch 11/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9163 - loss: 166.0914 - val_accuracy: 0.9194 - val_loss: 166.0821
# Epoch 12/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9163 - loss: 164.2868 - val_accuracy: 0.9203 - val_loss: 164.6501
# Epoch 13/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9167 - loss: 162.6838 - val_accuracy: 0.9194 - val_loss: 164.0139
# Epoch 14/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9170 - loss: 161.7230 - val_accuracy: 0.9197 - val_loss: 162.3623
# Epoch 15/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9176 - loss: 160.8545 - val_accuracy: 0.9200 - val_loss: 160.9659
# Epoch 16/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9171 - loss: 160.1415 - val_accuracy: 0.9194 - val_loss: 160.3764
# Epoch 17/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9184 - loss: 159.8910 - val_accuracy: 0.9200 - val_loss: 160.0147
# Epoch 18/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9176 - loss: 159.3786 - val_accuracy: 0.9191 - val_loss: 160.1159
# Epoch 19/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9180 - loss: 158.2664 - val_accuracy: 0.9191 - val_loss: 161.0741
# Epoch 20/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9184 - loss: 157.4805 - val_accuracy: 0.9193 - val_loss: 160.7066
# Epoch 21/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9192 - loss: 156.9313 - val_accuracy: 0.9191 - val_loss: 161.0239
# Epoch 22/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9194 - loss: 156.5030 - val_accuracy: 0.9179 - val_loss: 160.4117
# Epoch 23/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9191 - loss: 155.6116 - val_accuracy: 0.9173 - val_loss: 160.7139
# Epoch 24/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9194 - loss: 155.5755 - val_accuracy: 0.9185 - val_loss: 160.7797
# Epoch 25/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9204 - loss: 155.1469 - val_accuracy: 0.9183 - val_loss: 159.5297
# Epoch 26/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9192 - loss: 154.4770 - val_accuracy: 0.9172 - val_loss: 159.9976
# Epoch 27/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9201 - loss: 153.9357 - val_accuracy: 0.9178 - val_loss: 160.3402
# Epoch 28/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9198 - loss: 153.7997 - val_accuracy: 0.9177 - val_loss: 161.1635
# Epoch 29/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9204 - loss: 153.4980 - val_accuracy: 0.9179 - val_loss: 159.8854
# Epoch 30/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9205 - loss: 152.5003 - val_accuracy: 0.9174 - val_loss: 161.7460
# Epoch 31/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9211 - loss: 152.0879 - val_accuracy: 0.9185 - val_loss: 160.4499
# Epoch 32/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9209 - loss: 151.6842 - val_accuracy: 0.9180 - val_loss: 161.0380
# Epoch 33/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9211 - loss: 151.4685 - val_accuracy: 0.9178 - val_loss: 159.5354
# Epoch 34/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9208 - loss: 150.3577 - val_accuracy: 0.9178 - val_loss: 158.5045
# Epoch 35/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9207 - loss: 149.4289 - val_accuracy: 0.9171 - val_loss: 158.3766
# Epoch 36/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9231 - loss: 148.6778 - val_accuracy: 0.9182 - val_loss: 156.9282
# Epoch 37/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9229 - loss: 147.4756 - val_accuracy: 0.9183 - val_loss: 155.3049
# Epoch 38/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9232 - loss: 146.3515 - val_accuracy: 0.9182 - val_loss: 155.6712
# Epoch 39/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9241 - loss: 145.5030 - val_accuracy: 0.9194 - val_loss: 155.6400
# Epoch 40/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9254 - loss: 144.1106 - val_accuracy: 0.9202 - val_loss: 154.1907
# Epoch 41/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9256 - loss: 142.5549 - val_accuracy: 0.9199 - val_loss: 154.0866
# Epoch 42/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9258 - loss: 141.8101 - val_accuracy: 0.9216 - val_loss: 153.3436
# Epoch 43/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9283 - loss: 140.6751 - val_accuracy: 0.9205 - val_loss: 153.5853
# Epoch 44/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9289 - loss: 139.3603 - val_accuracy: 0.9208 - val_loss: 152.0062
# Epoch 45/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9302 - loss: 138.0913 - val_accuracy: 0.9207 - val_loss: 151.5203
# Epoch 46/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9302 - loss: 137.0036 - val_accuracy: 0.9222 - val_loss: 151.1475
# Epoch 47/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9301 - loss: 136.8556 - val_accuracy: 0.9229 - val_loss: 149.4021
# Epoch 48/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9312 - loss: 136.1844 - val_accuracy: 0.9225 - val_loss: 148.3701
# Epoch 49/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9325 - loss: 133.9221 - val_accuracy: 0.9238 - val_loss: 148.1714
# Epoch 50/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9331 - loss: 133.3672 - val_accuracy: 0.9229 - val_loss: 147.1982
# Epoch 51/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9338 - loss: 131.9281 - val_accuracy: 0.9248 - val_loss: 146.3066
# Epoch 52/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9338 - loss: 131.8199 - val_accuracy: 0.9241 - val_loss: 147.3914
# Epoch 53/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9343 - loss: 131.4658 - val_accuracy: 0.9268 - val_loss: 145.7796
# Epoch 54/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9350 - loss: 130.2088 - val_accuracy: 0.9268 - val_loss: 146.3352
# Epoch 55/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9357 - loss: 129.5052 - val_accuracy: 0.9268 - val_loss: 144.2436
# Epoch 56/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9362 - loss: 128.5934 - val_accuracy: 0.9261 - val_loss: 142.3844
# Epoch 57/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9374 - loss: 127.2959 - val_accuracy: 0.9245 - val_loss: 141.9594
# Epoch 58/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9389 - loss: 125.7561 - val_accuracy: 0.9262 - val_loss: 141.1530
# Epoch 59/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9385 - loss: 124.3359 - val_accuracy: 0.9258 - val_loss: 141.0212
# Epoch 60/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9410 - loss: 123.8721 - val_accuracy: 0.9268 - val_loss: 140.7664
# Epoch 61/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9394 - loss: 123.3041 - val_accuracy: 0.9266 - val_loss: 140.2897
# Epoch 62/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9402 - loss: 122.3897 - val_accuracy: 0.9280 - val_loss: 139.5263
# Epoch 63/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9412 - loss: 121.5774 - val_accuracy: 0.9281 - val_loss: 139.5320
# Epoch 64/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9390 - loss: 121.4714 - val_accuracy: 0.9287 - val_loss: 139.3921
# Epoch 65/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9418 - loss: 120.5877 - val_accuracy: 0.9261 - val_loss: 139.0900
# Epoch 66/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9439 - loss: 120.3596 - val_accuracy: 0.9283 - val_loss: 139.7733
# Epoch 67/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9436 - loss: 119.5229 - val_accuracy: 0.9273 - val_loss: 140.3077
# Epoch 68/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9426 - loss: 119.2512 - val_accuracy: 0.9293 - val_loss: 139.5918
# Epoch 69/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9438 - loss: 118.5018 - val_accuracy: 0.9294 - val_loss: 139.2422
# Epoch 70/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9456 - loss: 118.1003 - val_accuracy: 0.9267 - val_loss: 140.3055
# Epoch 71/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9442 - loss: 117.7654 - val_accuracy: 0.9286 - val_loss: 140.2997
# Epoch 72/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9448 - loss: 117.5169 - val_accuracy: 0.9283 - val_loss: 141.1997
# Epoch 73/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9447 - loss: 117.0465 - val_accuracy: 0.9287 - val_loss: 140.8967
# Epoch 74/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9441 - loss: 116.7883 - val_accuracy: 0.9285 - val_loss: 141.1356
# Epoch 75/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9465 - loss: 117.3368 - val_accuracy: 0.9277 - val_loss: 139.7538
# Epoch 76/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9474 - loss: 116.7021 - val_accuracy: 0.9271 - val_loss: 139.7017
# Epoch 77/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9485 - loss: 115.4871 - val_accuracy: 0.9260 - val_loss: 139.9918
# Epoch 78/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9475 - loss: 114.5541 - val_accuracy: 0.9250 - val_loss: 140.1715
# Epoch 79/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9492 - loss: 114.0642 - val_accuracy: 0.9260 - val_loss: 139.7929
# Epoch 80/300
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9494 - loss: 113.5151 - val_accuracy: 0.9239 - val_loss: 139.7766
# Epoch 80: early stopping
# Evaluation on training dataset:
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9241 - loss: 136.6177

# %%
importlib.reload(project);

project.plot_H_mass(model_dual2, val_batches)

# %%
project.true_vs_predict_H_mass(model_dual2, val_batches)

# %%
project.plot_all_labels(model_dual2, train_batches, output_targets)
# Out:
# True Higgs mass:  225.13698  and predicted: 239.91272

# %%
project.plot_all_pulls(model_dual2, val_batches, output_targets)
# Out:
# [H.m] sigma = 88.0861
# [H_pt] sigma = 44.5281
# [tau1_pt] sigma = 39.5089
# [tau2_pt] sigma = 39.9901
