# %% [markdown]
# ### Zadanie Domowe - Jakub Kuśmierski

# %%
import sys
sys.path.append('/Users/jakubkusmierski/Desktop/Uczenie_Maszynowe_2/modules')
import quadratic_equation as qef
import importlib
importlib.reload(qef)

nSamples = 1000
data = qef.quadraticEqGenerator(nSamples)
qef.plotQuadraticEqSolvability(data)

# %%
qef.plotQuadraticEqSolvability(data, interactive=True)
